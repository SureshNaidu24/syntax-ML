# %% [markdown]
# ## Problem 1: YouTube Video Performance Predictor

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# Dataset (from the image)
data = {
    'ctr': [3.2, 5.8, 2.1, 7.4, 4.5, 6.2, 1.8, 5.1, 3.9, 8.5,
            4.2, 2.8, 6.8, 3.5, 7.1, 2.4, 5.5, 4.8, 6.5, 3.1,
            7.8, 2.6, 5.3, 4.1, 6.9, 3.7, 8.1, 2.2, 5.9, 4.6],
    'total_views': [12000, 28000, 8500, 42000, 19000, 33000, 7000, 24000, 16000, 51000,
                    18000, 11000, 38000, 14500, 44000, 9500, 26000, 21000, 35000, 13000,
                    47000, 10000, 25000, 17500, 40000, 15000, 49000, 8000, 31000, 20000]
}

df = pd.DataFrame(data)
print(df.head())
print(df.describe())

plt.scatter(df['ctr'], df['total_views'])
plt.xlabel("Click Through Rate (CTR %)")
plt.ylabel("Total Views after 30 days")
plt.title("CTR vs Total Views")
plt.show()

X = df[['ctr']]
y = df['total_views']

model = LinearRegression()
model.fit(X, y)

print(f"Model equation: Views = {model.coef_[0]:.2f} * CTR + {model.intercept_:.2f}")

ctr_value = 8
predicted_views = model.predict([[ctr_value]])

print(f"\nExpected views for {ctr_value}% CTR: {int(predicted_views[0])}")
# Out:
#    ctr  total_views
# 0  3.2        12000
# 1  5.8        28000
# 2  2.1         8500
# 3  7.4        42000
# 4  4.5        19000
#              ctr   total_views
# count  30.000000     30.000000
# mean    4.880000  24433.333333
# std     1.943406  13537.134962
# min     1.800000   7000.000000
# 25%     3.275000  13375.000000
# 50%     4.700000  20500.000000
# 75%     6.425000  34500.000000
# max     8.500000  51000.000000
# Model equation: Views = 6879.61 * CTR + -9139.17
#
# Expected views for 8% CTR: 45897
# C:\Users\Suresh Mandamanedi\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ##Problem 2: Food Delivery Time Predictor

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Dataset from the image
data = {
    'distance_km': [2.5, 6.0, 1.2, 8.5, 3.8, 5.2, 1.8, 7.0, 4.5, 9.2, 2.0, 6.5, 3.2, 7.8, 4.0, 5.8, 1.5, 8.0, 3.5, 6.8, 2.2, 5.5, 4.2, 9.0, 2.8, 7.2, 3.0, 6.2, 4.8, 8.2],
    'prep_time_min': [10, 20, 8, 25, 12, 18, 7, 22, 15, 28, 9, 19, 11, 24, 14, 17, 6, 26, 13, 21, 10, 16, 14, 27, 11, 23, 12, 18, 15, 25],
    'delivery_time_min': [18, 38, 12, 52, 24, 34, 14, 45, 29, 58, 15, 40, 21, 50, 27, 35, 11, 54, 23, 43, 17, 32, 26, 56, 19, 47, 20, 37, 30, 53]
}

df = pd.DataFrame(data)

plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.scatter(df['distance_km'], df['delivery_time_min'], color='blue')
plt.title('Distance vs Delivery Time')
plt.xlabel('Distance (km)')
plt.ylabel('Time (min)')

plt.subplot(1, 2, 2)
plt.scatter(df['prep_time_min'], df['delivery_time_min'], color='green')
plt.title('Prep Time vs Delivery Time')
plt.xlabel('Prep Time (min)')

plt.tight_layout()
plt.show()



X = df[['distance_km', 'prep_time_min']]
y = df['delivery_time_min']
model = LinearRegression()
model.fit(X, y)
coefficients = pd.DataFrame(model.coef_, X.columns, columns=['Coefficient'])
print("Model Coefficients:")
print(coefficients)

# Vikram's scenario: 
vikram_test = np.array([[7.0, 15.0]])
predicted_time = model.predict(vikram_test)

print(f"\n--- Vikram's Prediction ---")
print(f"Distance: 7 km")
print(f"Prep Time: 15 min")
print(f"Predicted Delivery Time: {predicted_time[0]:.2f} minutes")
# Out:
# Model Coefficients:
#                Coefficient
# distance_km       2.735527
# prep_time_min     1.230017
#
# --- Vikram's Prediction ---
# Distance: 7 km
# Prep Time: 15 min
# Predicted Delivery Time: 36.08 minutes
# C:\Users\Suresh Mandamanedi\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
